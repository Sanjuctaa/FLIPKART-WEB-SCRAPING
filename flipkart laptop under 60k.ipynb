# %%
import requests 
import pandas as pd
from bs4 import BeautifulSoup

product_name=[]
prices=[]
description=[]
reviews=[]


for i in range(2,12):
    url= "https://flipkart.com/search?q=laptops+under+60k&amp;as=on&amp;as-show=on&amp;otracker=AS_Query_OrganicAutoSuggest_7_14_na_na_ps&amp;otracker1=AS_Query_OrganicAutoSuggest_7_14_na_na_ps&amp;as-pos=7&amp;as-type=RECENT&amp;suggestionId=laptops+under+60k&amp;requestId=5402f762-31cc-416e-ae97-362b034030d6&amp;as-searchtext=laptops+under+&amp;page="+str(i)
    r= requests.get(url)
    soup= BeautifulSoup(r.text,"lxml")

    box= soup.find("div",class_="_1YokD2 _3Mn1Gg")


    names= box.find_all("div",class_= "_4rR01T")

    for i in names:
        name= i.text
        product_name.append(name)


    price=box.find_all("div",class_="_30jeq3 _1_WHN1")

    for i in price:
        p=i.text
        prices.append(p)
    

    rev= box.find_all("div",class_="_3LWZlK")

    for i in rev:
        r=i.text
        reviews.append(r)
    

    desc= box.find_all("ul",class_="_1xgFaf")

    for i in desc:
        d=i.text
        description.append(d)

# %%
print

# %%
data=pd.DataFrame({"Product Name":product_name,"Price":prices,"Description":description})
data
# Out:
#                                           Product Name    Price  \
# 0    Acer One14 Backlit Intel Core i5 11th Gen 1155...  ₹34,990
# 1    HP AMD Ryzen 5 Hexa Core 5500U - (16 GB/512 GB...  ₹45,490
# 2    HP Intel Core i5 12th Gen 1235U - (16 GB/512 G...  ₹53,990
# 3    ASUS Vivobook 15 Intel Core i5 11th Gen 1135G7...  ₹43,990
# 4    ASUS TUF Gaming F15 with 90WHr Battery Intel C...  ₹59,990
# ..                                                 ...      ...
# 235  DELL Intel Core i5 12th Gen 1235U - (8 GB/512 ...  ₹46,470
# 236  HP AMD Ryzen 5 Hexa Core 5500U - (8 GB/512 GB ...  ₹39,590
# 237  DELL Intel Core i5 12th Gen 1235U - (8 GB/512 ...  ₹49,000
# 238  Acer Aspire 5 Gaming Intel Core i5 12th Gen 12...  ₹54,999
# 239  ASUS Vivobook S 14 Flip (2023) AMD Ryzen 5 Hex...  ₹74,990
#
#                                            Description
# 0    Intel Core i5 Processor (11th Gen)16 GB DDR4 R...
# 1    AMD Ryzen 5 Hexa Core Processor16 GB DDR4 RAM6...
# 2    Intel Core i5 Processor (12th Gen)16 GB DDR4 R...
# 3    Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...
# 4    Intel Core i5 Processor (11th Gen)16 GB DDR4 R...
# ..                                                 ...
# 235  Intel Core i5 Processor (12th Gen)8 GB DDR4 RA...
# 236  AMD Ryzen 5 Hexa Core Processor8 GB DDR4 RAM64...
# 237  Intel Core i5 Processor (12th Gen)8 GB DDR4 RA...
# 238  Intel Core i5 Processor (12th Gen)16 GB DDR4 R...
# 239  AMD Ryzen 5 Hexa Core Processor16 GB DDR4 RAMW...
#
# [240 rows x 3 columns]

# %%
data.to_csv('C:/Users/sanju/Desktop/excel files/laptop_under_60k.csv')
